# %% [markdown]
# <a href="https://colab.research.google.com/github/maggiechurch741/PPR_Pond_Mapper/blob/main/docs/notebooks/get_DSWx-HLS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![image](https://jupyterlite.rtfd.io/en/latest/_static/badge.svg)](https://demo.leafmap.org/lab/index.html?path=notebooks/101_nasa_opera.ipynb)
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/leafmap/blob/master/docs/notebooks/101_nasa_opera.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/opengeos/leafmap/HEAD)
#
# **Searching and Visualizing NASA OPERA Data Products Interactively**
#
#
# Started in April 2021, the Observational Products for End-Users from Remote Sensing Analysis ([OPERA](https://www.jpl.nasa.gov/go/opera)) project at the Jet Propulsion Laboratory collects data from satellite radar and optical instruments to generate six product suites:
#
# * a near-global Surface Water Extent product suite
# * a near-global Surface Disturbance product suite
# * a near-global Radiometric Terrain Corrected product
# * a North America Coregistered Single Look complex product suite
# * a North America Displacement product suite
# * a North America Vertical Land Motion product suite
#
# This notebook demonstrates how to search and visualize NASA OPERA data products interactively using the `leafmap` Python package.

# %%
# %pip install -U "leafmap[raster]" earthaccess
# Out:
# Collecting earthaccess
#   Downloading earthaccess-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting leafmap[raster]
#   Downloading leafmap-0.48.6-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (0.9.18)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (0.12.45)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (1.3.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (0.20.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (5.2.0)
# Collecting geojson (from leafmap[raster])
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (1.1.1)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (2.0.2)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (0.20.0)
# Collecting ipyvuetify (from leafmap[raster])
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (7.7.1)
# Collecting maplibre (from leafmap[raster])
#   Downloading maplibre-0.3.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (5.24.1)
# Collecting pystac-client (from leafmap[raster])
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: python-box in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (7.3.2)
# Requirement already satisfied: scooby in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (0.10.1)
# Collecting whiteboxgui (from leafmap[raster])
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (2025.4.0)
# Collecting localtileserver>=0.10.6 (from leafmap[raster])
#   Downloading localtileserver-0.10.6-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-server-proxy (from leafmap[raster])
#   Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting rio-cogeo (from leafmap[raster])
#   Downloading rio_cogeo-5.4.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting rioxarray (from leafmap[raster])
#   Downloading rioxarray-0.19.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting netcdf4 (from leafmap[raster])
#   Downloading netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting d2spy (from leafmap[raster])
#   Downloading d2spy-0.2.8-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: h5netcdf in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (1.6.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (3.14.0)
# Collecting opera-utils (from leafmap[raster])
#   Downloading opera_utils-0.23.3-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from leafmap[raster]) (5.9.5)
# Requirement already satisfied: fsspec>=2022.11 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (2025.3.0)
# Requirement already satisfied: importlib-resources>=6.3.2 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (6.5.2)
# Collecting multimethod>=1.8 (from earthaccess)
#   Downloading multimethod-2.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting pqdm>=0.1 (from earthaccess)
#   Downloading pqdm-0.2.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting python-cmr>=0.10.0 (from earthaccess)
#   Downloading python_cmr-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (2.32.3)
# Collecting s3fs>=2022.11 (from earthaccess)
#   Downloading s3fs-2025.7.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting tinynetrc>=1.3.1 (from earthaccess)
#   Downloading tinynetrc-1.3.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from earthaccess) (4.14.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (8.2.1)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (3.1.1)
# Collecting Flask-Caching (from localtileserver>=0.10.6->leafmap[raster])
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver>=0.10.6->leafmap[raster])
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting flask-restx>=1.3.0 (from localtileserver>=0.10.6->leafmap[raster])
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver>=0.10.6->leafmap[raster])
#   Downloading rio_tiler-7.8.1-py3-none-any.whl.metadata (12 kB)
# Collecting server-thread (from localtileserver>=0.10.6->leafmap[raster])
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.11/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (3.1.3)
# Collecting bounded-pool-executor (from pqdm>=0.1->earthaccess)
#   Downloading bounded_pool_executor-0.0.3-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from pqdm>=0.1->earthaccess) (4.67.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from python-cmr>=0.10.0->earthaccess) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26->earthaccess) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26->earthaccess) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26->earthaccess) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26->earthaccess) (2025.7.14)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs>=2022.11->earthaccess)
#   Downloading aiobotocore-2.23.2-py3-none-any.whl.metadata (25 kB)
# Collecting fsspec>=2022.11 (from earthaccess)
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from s3fs>=2022.11->earthaccess) (3.12.14)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.11/dist-packages (from anywidget->leafmap[raster]) (0.14.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap[raster]) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap[raster]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap[raster]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap[raster]) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap[raster]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap[raster]) (3.0.15)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.11/dist-packages (from bqplot->leafmap[raster]) (0.2.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->leafmap[raster]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->leafmap[raster]) (2025.2)
# Collecting exifread<4.0.0,>=3.0.0 (from d2spy->leafmap[raster])
#   Downloading exifread-3.3.2-py3-none-any.whl.metadata (10 kB)
# Collecting geojson-pydantic<2.0.0,>=1.1.1 (from d2spy->leafmap[raster])
#   Downloading geojson_pydantic-1.2.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting rasterio<2.0.0,>=1.3.11 (from d2spy->leafmap[raster])
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas->leafmap[raster]) (0.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas->leafmap[raster]) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->leafmap[raster]) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->leafmap[raster]) (2.1.1)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium->leafmap[raster]) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium->leafmap[raster]) (3.1.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown->leafmap[raster]) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown->leafmap[raster]) (3.18.0)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet->leafmap[raster]) (0.20.0)
# Collecting ipyvue<2,>=1.7 (from ipyvuetify->leafmap[raster])
#   Downloading ipyvue-1.11.2-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting jupyter-server>=1.24.0 (from jupyter-server-proxy->leafmap[raster])
#   Downloading jupyter_server-2.16.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->leafmap[raster])
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server-proxy->leafmap[raster]) (6.4.2)
# Collecting eval-type-backport (from maplibre->leafmap[raster])
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pydantic>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from maplibre->leafmap[raster]) (2.11.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->leafmap[raster]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->leafmap[raster]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->leafmap[raster]) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->leafmap[raster]) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->leafmap[raster]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->leafmap[raster]) (3.2.3)
# Collecting cftime (from netcdf4->leafmap[raster])
#   Downloading cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: pooch>=1.7 in /usr/local/lib/python3.11/dist-packages (from opera-utils->leafmap[raster]) (1.8.2)
# Collecting tyro>=0.9 (from opera-utils->leafmap[raster])
#   Downloading tyro-0.9.26-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->leafmap[raster]) (8.5.0)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac-client->leafmap[raster])
#   Downloading pystac-1.13.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting morecantile<7.0,>=5.0 (from rio-cogeo->leafmap[raster])
#   Downloading morecantile-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: xarray>=2024.7.0 in /usr/local/lib/python3.11/dist-packages (from rioxarray->leafmap[raster]) (2025.7.1)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.11/dist-packages (from whiteboxgui->leafmap[raster]) (0.2.2)
# Collecting whitebox (from whiteboxgui->leafmap[raster])
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess)
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting botocore<1.39.9,>=1.39.7 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess)
#   Downloading botocore-1.39.8-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess) (6.6.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (1.20.1)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from flask<4,>=2.0.0->localtileserver>=0.10.6->leafmap[raster]) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from flask<4,>=2.0.0->localtileserver>=0.10.6->leafmap[raster]) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from flask<4,>=2.0.0->localtileserver>=0.10.6->leafmap[raster]) (3.0.2)
# Collecting aniso8601>=0.82 (from flask-restx>=1.3.0->localtileserver>=0.10.6->leafmap[raster])
#   Downloading aniso8601-10.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from flask-restx>=1.3.0->localtileserver>=0.10.6->leafmap[raster]) (4.25.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (26.2.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->leafmap[raster])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (4.9.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (25.1.0)
# Collecting jupyter-client>=6.1.12 (from ipykernel>=4.5.1->ipywidgets->leafmap[raster])
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (5.8.1)
# Collecting jupyter-events>=0.11.0 (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (5.10.4)
# Collecting overrides>=5.0 (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.8.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.7->opera-utils->leafmap[raster]) (4.3.8)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.3->maplibre->leafmap[raster]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.3->maplibre->leafmap[raster]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.3->maplibre->leafmap[raster]) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.8.2->python-cmr>=0.10.0->earthaccess) (1.17.0)
# Collecting affine (from rasterio<2.0.0,>=1.3.11->d2spy->leafmap[raster])
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting cligj>=0.5 (from rasterio<2.0.0,>=1.3.11->d2spy->leafmap[raster])
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio<2.0.0,>=1.3.11->d2spy->leafmap[raster])
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro>=0.9->opera-utils->leafmap[raster]) (0.17.0)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro>=0.9->opera-utils->leafmap[raster]) (13.9.4)
# Collecting shtab>=1.5.6 (from tyro>=0.9->opera-utils->leafmap[raster])
#   Downloading shtab-1.7.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro>=0.9->opera-utils->leafmap[raster]) (4.4.4)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (6.5.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown->leafmap[raster]) (2.7)
# Collecting cachelib>=0.9.0 (from Flask-Caching->localtileserver>=0.10.6->leafmap[raster])
#   Downloading cachelib-0.13.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->leafmap[raster]) (1.7.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (5.5.2)
# Collecting color-operations (from rio-tiler->localtileserver>=0.10.6->leafmap[raster])
#   Downloading color_operations-0.2.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (0.28.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (2.11.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from server-thread->localtileserver>=0.10.6->leafmap[raster]) (0.35.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver>=0.10.6->leafmap[raster]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver>=0.10.6->leafmap[raster]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver>=0.10.6->leafmap[raster]) (0.26.0)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (6.0.2)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.3.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.21.1)
# Collecting jupyter-client>=6.1.12 (from ipykernel>=4.5.1->ipywidgets->leafmap[raster])
#   Downloading jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (1.3.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (0.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro>=0.9->opera-utils->leafmap[raster]) (3.0.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (0.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.4.0)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (3.0.0)
# Collecting rfc3987-syntax>=1.1.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading rfc3987_syntax-1.1.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (24.11.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.9->opera-utils->leafmap[raster]) (0.1.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (0.2.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.22)
# Collecting lark>=1.2.2 (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster])
#   Downloading types_python_dateutil-2.9.0.20250708-py3-none-any.whl.metadata (1.9 kB)
# Downloading earthaccess-0.14.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.7 MB/s eta 0:00:00
# Downloading localtileserver-0.10.6-py3-none-any.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 55.1 MB/s eta 0:00:00
# Downloading multimethod-2.0-py3-none-any.whl (9.8 kB)
# Downloading pqdm-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Downloading python_cmr-0.13.0-py3-none-any.whl (14 kB)
# Downloading s3fs-2025.7.0-py3-none-any.whl (30 kB)
# Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.6/199.6 kB 15.7 MB/s eta 0:00:00
# Downloading tinynetrc-1.3.1-py2.py3-none-any.whl (3.9 kB)
# Downloading d2spy-0.2.8-py3-none-any.whl (36 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 63.3 MB/s eta 0:00:00
# Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl (37 kB)
# Downloading leafmap-0.48.6-py2.py3-none-any.whl (568 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.1/568.1 kB 32.3 MB/s eta 0:00:00
# Downloading maplibre-0.3.5-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 62.0 MB/s eta 0:00:00
# Downloading netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 95.7 MB/s eta 0:00:00
# Downloading opera_utils-0.23.3-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 6.8 MB/s eta 0:00:00
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.6 MB/s eta 0:00:00
# Downloading rio_cogeo-5.4.2-py3-none-any.whl (21 kB)
# Downloading rioxarray-0.19.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 kB 5.1 MB/s eta 0:00:00
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 6.4 MB/s eta 0:00:00
# Downloading aiobotocore-2.23.2-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.3/84.3 kB 6.6 MB/s eta 0:00:00
# Downloading exifread-3.3.2-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 3.9 MB/s eta 0:00:00
# Downloading flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 77.2 MB/s eta 0:00:00
# Downloading geojson_pydantic-1.2.0-py3-none-any.whl (8.7 kB)
# Downloading ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 74.0 MB/s eta 0:00:00
# Downloading jupyter_server-2.16.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 23.6 MB/s eta 0:00:00
# Downloading morecantile-6.2.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.1 MB/s eta 0:00:00
# Downloading pystac-1.13.0-py3-none-any.whl (206 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.8/206.8 kB 17.1 MB/s eta 0:00:00
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 73.2 MB/s eta 0:00:00
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading tyro-0.9.26-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 11.2 MB/s eta 0:00:00
# Downloading bounded_pool_executor-0.0.3-py3-none-any.whl (3.4 kB)
# Downloading cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 62.7 MB/s eta 0:00:00
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading rio_tiler-7.8.1-py3-none-any.whl (269 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 22.4 MB/s eta 0:00:00
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 6.3 MB/s eta 0:00:00
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading aniso8601-10.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.5 MB/s eta 0:00:00
# Downloading botocore-1.39.8-py3-none-any.whl (13.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 94.3 MB/s eta 0:00:00
# Downloading cachelib-0.13.0-py3-none-any.whl (20 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.1 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 12.2 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading shtab-1.7.2-py3-none-any.whl (14 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading color_operations-0.2.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.2/195.2 kB 16.7 MB/s eta 0:00:00
# Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading rfc3987_syntax-1.1.0-py3-none-any.whl (8.0 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.0 MB/s eta 0:00:00
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 9.0 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20250708-py3-none-any.whl (17 kB)
# Installing collected packages: tinynetrc, bounded-pool-executor, aniso8601, whitebox, uri-template, types-python-dateutil, simpervisor, shtab, rfc3986-validator, rfc3339-validator, python-json-logger, pqdm, overrides, multimethod, lark, jmespath, jedi, geojson, fsspec, fqdn, exifread, eval-type-backport, color-operations, cligj, click-plugins, cftime, cachelib, aioitertools, affine, server-thread, rfc3987-syntax, rasterio, python-cmr, pystac, netcdf4, jupyter-server-terminals, jupyter-client, botocore, arrow, tyro, morecantile, maplibre, isoduration, geojson-pydantic, flask-cors, Flask-Caching, aiobotocore, s3fs, rioxarray, rio-tiler, rio-cogeo, opera-utils, flask-restx, d2spy, pystac-client, localtileserver, jupyter-events, earthaccess, jupyter-server, jupyter-server-proxy, ipyvue, whiteboxgui, ipyvuetify, leafmap
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.16.0
#     Uninstalling jupyter-server-1.16.0:
#       Successfully uninstalled jupyter-server-1.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.7.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.7.0 which is incompatible.
# Successfully installed Flask-Caching-2.3.1 affine-2.4.0 aiobotocore-2.23.2 aioitertools-0.12.0 aniso8601-10.0.1 arrow-1.3.0 botocore-1.39.8 bounded-pool-executor-0.0.3 cachelib-0.13.0 cftime-1.6.4.post1 click-plugins-1.1.1.2 cligj-0.7.2 color-operations-0.2.0 d2spy-0.2.8 earthaccess-0.14.0 eval-type-backport-0.2.2 exifread-3.3.2 flask-cors-6.0.1 flask-restx-1.3.0 fqdn-1.5.1 fsspec-2025.7.0 geojson-3.2.0 geojson-pydantic-1.2.0 ipyvue-1.11.2 ipyvuetify-1.11.3 isoduration-20.11.0 jedi-0.19.2 jmespath-1.0.1 jupyter-client-7.4.9 jupyter-events-0.12.0 jupyter-server-2.16.0 jupyter-server-proxy-4.4.0 jupyter-server-terminals-0.5.3 lark-1.2.2 leafmap-0.48.6 localtileserver-0.10.6 maplibre-0.3.5 morecantile-6.2.0 multimethod-2.0 netcdf4-1.7.2 opera-utils-0.23.3 overrides-7.7.0 pqdm-0.2.0 pystac-1.13.0 pystac-client-0.9.0 python-cmr-0.13.0 python-json-logger-3.3.0 rasterio-1.4.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rfc3987-syntax-1.1.0 rio-cogeo-5.4.2 rio-tiler-7.8.1 rioxarray-0.19.0 s3fs-2025.7.0 server-thread-0.3.0 shtab-1.7.2 simpervisor-1.0.0 tinynetrc-1.3.1 types-python-dateutil-2.9.0.20250708 tyro-0.9.26 uri-template-1.3.0 whitebox-2.3.6 whiteboxgui-2.3.0

# %%
# !pip install boto3 rasterio
# Out:
# Collecting boto3
#   Downloading boto3-1.39.15-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.11/dist-packages (1.4.3)
# Collecting botocore<1.40.0,>=1.39.15 (from boto3)
#   Downloading botocore-1.39.15-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3) (1.0.1)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3)
#   Downloading s3transfer-0.13.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: affine in /usr/local/lib/python3.11/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.7.14)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.2.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.11/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.40.0,>=1.39.15->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.40.0,>=1.39.15->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.40.0,>=1.39.15->boto3) (1.17.0)
# Downloading boto3-1.39.15-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 4.7 MB/s eta 0:00:00
# Downloading botocore-1.39.15-py3-none-any.whl (13.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 98.5 MB/s eta 0:00:00
# Downloading s3transfer-0.13.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: botocore, s3transfer, boto3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.39.8
#     Uninstalling botocore-1.39.8:
#       Successfully uninstalled botocore-1.39.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.23.2 requires botocore<1.39.9,>=1.39.7, but you have botocore 1.39.15 which is incompatible.
# Successfully installed boto3-1.39.15 botocore-1.39.15 s3transfer-0.13.1

# %%
import leafmap

# %% [markdown]
# To download and access the data, you will need to create an Earthdata login. You can register for an account at [urs.earthdata.nasa.gov](https://urs.earthdata.nasa.gov).

# %%
leafmap.nasa_data_login()
# Out:
# Enter your Earthdata Login username: mgchurch247
# Enter your Earthdata password: ··········

# %%
m = leafmap.Map(center=[36.1711, -114.6581], zoom=10, height="700px")
m.add_basemap("Satellite")
m.add("NASA_OPERA")
m
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-5-1048821436.py in <cell line: 0>()
#       1 m = leafmap.Map(center=[36.1711, -114.6581], zoom=10, height="700px")
#       2 m.add_basemap("Satellite")
# ----> 3 m.add("NASA_OPERA")
#       4 m
#
# /usr/local/lib/python3.11/dist-packages/leafmap/leafmap.py in add(self, obj, index, **kwargs)
#     238                     from .toolbar import nasa_opera_gui
#     239
# --> 240                     nasa_opera_gui(self, **kwargs)
#     241                 elif obj == "inspector":
#     242                     from .toolbar import inspector_gui
#
# /usr/local/lib/python3.11/dist-packages/leafmap/toolbar.py in nasa_opera_gui(m, position, opened, default_dataset, backend, **kwargs)
#    6776     import pandas as pd
#    6777     from datetime import datetime
# -> 6778     import boto3
#    6779     import rasterio as rio
#    6780     from rasterio.session import AWSSession
#
# ModuleNotFoundError: No module named 'boto3'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Pan and zoom to your area of interest. Select a dataset from the Short Name dropdown list. Click the "Search" button to load the available datasets for the region. The footprints of the datasets will be displayed on the map. Click on a footprint to display the metadata of the dataset.
#
# ![image](https://github.com/user-attachments/assets/1fdb58b5-9faa-4666-96f3-0fb1869f7551)

# %% [markdown]
# The footprints of the datasets can be accessed as a GeoPandas GeoDataFrame:

# %%
m._NASA_DATA_GDF.head()

# %% [markdown]
# There are two options to visualize OPERA product granule(s):
#
# - Option 1: Select a dataset from the Dataset dropdown menu, and select a corresponding layer from the Layer dropdown menu. Choose a colormap (if colormap is blank, the default OPERA colormap from the metadata will be used). Click on the "Display (Single)" button to display the selected granule layer on the map.
#
# - Option 2: Select a layer from the Layer dropdown menu. Choose a colormap (if colormap is blank, the default OPERA colormap from the metadata will be used). Click on the "Display (Mosaic)" button to display a mosaic of the granules shown on the map (Currently only supported for geotiff products; RTC/DSWx/DIST).

# %% [markdown]
# The OPERA Dynamic Surface Water Extent from Sentinel-1 (DSWx-S1) water classification (WTR) layer over Lake Mead in southern Nevada, USA:
#
# ![image](https://github.com/user-attachments/assets/0ff253f3-e6b0-4bdd-8592-750b05414db8)
#
# The OPERA Surface Disturbance from Harmonized Landsat and Sentinel-2 (DIST-HLS) vegetation disturbance status (VEG-DIST-STATUS) layer over a wildfire-impacted region of northern Quebec, Canada:
#
# ![image](https://github.com/user-attachments/assets/fbb02210-8654-425b-84d3-620d12708e6a)

# %% [markdown]
# The selected layer added to the map can be accessed as a xarray Dataset:

# %%
m._NASA_DATA_DS

# %% [markdown]
# To save the displayed layer as a GeoTIFF file:

# %%
m._NASA_DATA_DS.rio.to_raster("DSWx.tif")

# %% [markdown]
# To download all the available datasets for the region:

# %%
leafmap.nasa_data_download(
    m._NASA_DATA_RESULTS[:1], out_dir="data", keywords=["_WTR.tif"]
)
